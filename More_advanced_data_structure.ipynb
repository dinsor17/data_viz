# %% [markdown]
# <a href="https://colab.research.google.com/github/dinsor17/data_viz/blob/main/More_advanced_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ที่เรียนไปแล้วมี 1 ตัวคือ list หน้าตาประมาณนี้

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ข้อดีของ list (ที่ดีกว่าภาษาซี) 
#1.ช่องเก็บของได้หลายอย่างเก็บได้หมดเลย 
#2.มันมีลิสสะไลด์ซิ่ง

# %% [markdown]
# #Dictionary
#
# สามารถ index ด้วยอะไรก็ได้ แต่ลำดับจะหายไป

# %%
ex_dict = {'a':10,'1':1,'stat':5}#curly brackets ในการบอกว่าเป็น dict

# %%
ex_dict['stat']
# Out:
# 5

# %%
ex2_dict = {'1':'one',2:'two',3:'three'}

# %%
ex2_dict[2]
# Out:
# 'two'

# %% [markdown]
# #### การเพิ่มสมาชิกใน dict

# %%
ex2_dict[0] = 'zero'

# %%
ex2_dict
# Out:
# {0: 'zero', '1': 'one', 2: 'two', 3: 'three'}

# %% [markdown]
# คำสั่งพิเศษ

# %%
ex2_dict.keys() #ข้อจำกัดของdicคือมันไม่มีลำดับ ถ้าอยากให้มีลำดับต้องใช้ list
# Out:
# dict_keys(['1', 2, 3, 0])

# %%
for index in ex2_dict.keys():
     print(index)
# Out:
# 1
# 2
# 3
# 0

# %%
ex2_dict.values() #ข้างหน้าเรียก keys ข้างหลังเรียก values
# Out:
# dict_values(['one', 'two', 'three', 'zero'])

# %%
index
# Out:
# 0

# %% [markdown]
# ความสำคัญของ dict คือเอาไปใช้ร่วมกับ Dataframe ของ pandas

# %% [markdown]
# #Numpy array

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# numpy คือ package ที่ทำงานเกี่ยวกับ array ของตัวเลข (ที่มีคนเขียนขึ้นมาและนิยมใช้)
#
# numpy -> number python

# %%
import numpy #วิธีเรียกใช้งาน package

# %% [markdown]
# ### สร้าง numpy array

# %%
ex_2d_array = numpy.array([[5.2,3.0,4.5],[9.1,0.1,0.3]])
print(ex_2d_array)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %% [markdown]
# ### การชี้ค่าใน numpy array

# %%
ex_2d_array[1,2]
# Out:
# 0.3

# %%
list_x = [[5.2,3.0,4.5],[9.1,0.1,0.3]] #การชี้ list
print(len(list_x))                             #เรียกดูจำนวนสมาชิก
print(list_x[1])      #สมาชิกตัวที่2      #list มันนับจาก 0,1,2... 
print(list_x[1][2])
# Out:
# 2
# [9.1, 0.1, 0.3]
# 0.3

# %% [markdown]
# ###Operations

# %%
ex2_2d_array = numpy.array([[1,0,0],[0,0,1]])
print(ex2_2d_array)
print(ex_2d_array)
# Out:
# [[1 0 0]
#  [0 0 1]]
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %%
ex_2d_array.shape #ตรวจสอบขนาด matrix
# Out:
# (2, 3)

# %%
ex_2d_array + ex2_2d_array
# Out:
# array([[6.2, 3. , 4.5],
#        [9.1, 0.1, 1.3]])

# %%
list_x = [[5.2,3.0,4.5],[9.1,0.1,0.3]]
list_x2 = [[1,0,0],[0,0,1]]

list_x + list_x2 #การ+ของlist คือเอามาต่อกัน สมาชิกมารวมกัน
# Out:
# [[5.2, 3.0, 4.5], [9.1, 0.1, 0.3], [1, 0, 0], [0, 0, 1]]

# %%
ex_2d_array - ex2_2d_array #การคูณแบบ array เอาตำแหน่งเดียวกันมาคูณกัน
# Out:
# array([[ 4.2,  3. ,  4.5],
#        [ 9.1,  0.1, -0.7]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# matix multiplication

# %%
ex_2d_array * ex2_2d_array #คำตอบไม่ถูก #การคูณแบบ array เอาตำแหน่งเดียวกันมาคูณกัน
# Out:
# array([[5.2, 0. , 0. ],
#        [0. , 0. , 0.3]])

# %%
numpy.dot(ex_2d_array,ex2_2d_array) #มันคูณกันไม่ได้เพราะหลักแถวไม่เท่ากัน
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5e20d1f10c18> in <module>()
# ----> 1 numpy.dot(ex_2d_array,ex2_2d_array) #มันคูณกันไม่ได้เพราะหลักแถวไม่เท่ากัน
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)

# %%
print(ex_2d_array)
print(ex_2d_array.T)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]
# [[5.2 9.1]
#  [3.  0.1]
#  [4.5 0.3]]

# %%
dot_mat = numpy.dot(ex_2d_array,ex2_2d_array.T)
print(dot_mat)
# Out:
# [[5.2 4.5]
#  [9.1 0.3]]

# %%
numpy.linalg.det(dot_mat)
# Out:
# -39.389999999999986

# %% [markdown]
# search google -> stackoverflow หรือ web ของ package สำหรับ operations อื่นๆ

# %% [markdown]
# ## matrix slicing

# %%
print(ex_2d_array)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %%
ex_2d_array[1,1:]
# Out:
# array([0.1, 0.3])

# %%
ex_2d_array[:,:2]
# Out:
# array([[5.2, 3. ],
#        [9.1, 0.1]])

# %% [markdown]
# จบวันที่ 14 Jan 2021

# %% [markdown]
# HW 5 เขียน function คูณ matrix
#
# แล้ว test กับ matrix ขนาด
#
# - (2,3)*(3,2)
# - (4,4)*(4,1)
# - (2,2)*(2,2)

# %% [markdown]
# ##random ones, zeros

# %% [markdown]
# ###input มี 2 ชนิด จำเป็นกับไม่จำเป็น

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np #import unmpy แล้วตั้งเป็น np (จริงๆตั้งเป็นอะไรก็ได้แต่คนอื่นจะดูไม่รู้เรื่อง)

# %% [markdown]
# zeros

# %%
np.zeros(2)
# Out:
# array([0., 0.])

# %%
np.zeros((2,3)) # สร้าง array ที่ทุกค่าเป็น 0
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [markdown]
# ones

# %%
np.ones((2,3))  # สร้าง array ที่ทุกค่าเป็น 1
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %% [markdown]
# #Matrix Operation (scalar multiplication)

# %%
M_one = np.ones((2,3))

2*M_one
# Out:
# array([[2., 2., 2.],
#        [2., 2., 2.]])

# %% [markdown]
# random

# %%
np.random.random((3,3)) #เป็น Nominal ##sample from  nominal distribution mean=0 std=1
#ตั้งแต่ศูนย์ถึง1มีโอกาสเกิดเท่ากัน
# Out:
# array([[0.50712333, 0.88652394, 0.80999691],
#        [0.12324548, 0.43520088, 0.29035599],
#        [0.50214558, 0.04231089, 0.61999688]])

# %%
np.random.rand(3,3) #uniform random (0,1] ศูนย์ถึงหนึ่ง
# Out:
# array([[0.58021553, 0.73623477, 0.12449665],
#        [0.46456431, 0.46328138, 0.94782983],
#        [0.89099313, 0.6080954 , 0.62286138]])

# %%
#random.choice คือสุ่มจากค่าที่เรากำหนด
np.random.choice([1,2,3,'a','b','c'])
# Out:
# 'c'

# %%
np.random.choice([1,2,3,28,11,100], size = 2)
# Out:
# array([1, 2])

# %%
np.random.choice([1,2,3,28,11,100], size = (2,3))
# Out:
# array([[ 3,  2, 28],
#        [11,  3,  2]])

# %%
np.random.choice([1,2,3,28,11,100], size = (2,3), replace=False)
# Out:
# array([[  2,   3,   1],
#        [ 11,  28, 100]])

# %%
np.random.choice(['A','B','C','D','F'], size = 35, p = [0.1,0.2,0.4,0.29,0.01])
# Out:
# array(['D', 'D', 'B', 'C', 'B', 'C', 'B', 'C', 'C', 'D', 'D', 'D', 'B',
#        'A', 'B', 'C', 'D', 'B', 'D', 'D', 'C', 'C', 'D', 'B', 'D', 'C',
#        'D', 'C', 'C', 'C', 'B', 'B', 'C', 'C', 'B'], dtype='<U1')

# %% [markdown]
# #เฉลย HW5 Matrix Multiplication

# %%
def mat_mul(A,B):
      C = np.zeros((A.shape[0],B.shape[1])) #เตรียมขนาดของ matrix ผลลัพธ์
      for r_a in range(A.shape[0]) :
           for c_b in range(B.shape[1]) :
                for every_element in range (A.shape[1]) :
                     C[r_a,c_b] = C[r_a,c_b] + (A[r_a,every_element])* B[every_element,c_b]
      return C

# %%
mat1 = np.array([[1,2,3],[4,5,6]])
mat2 = np.array([[7,8],[9,10],[11,12]])

# %%
mat_mul(mat1,mat2)
# Out:
# array([[ 58.,  64.],
#        [139., 154.]])
